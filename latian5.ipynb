# %%
import pandas as pd
import numpy as np

# %%
le = pd.read_csv("Life Expectancy Data.csv")
le.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
le.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
le.drop(['Measles ', 'Year', 'under-five deaths ', 'Total expenditure', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources'], axis=1, inplace = True)

# %%
le.head()
# Out:
#        Country      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  Developing              65.0            263.0             62
# 1  Afghanistan  Developing              59.9            271.0             64
# 2  Afghanistan  Developing              59.9            268.0             66
# 3  Afghanistan  Developing              59.5            272.0             69
# 4  Afghanistan  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B   BMI   Polio  Diphtheria   \
# 0     0.01               71.279624         65.0   19.1    6.0         65.0
# 1     0.01               73.523582         62.0   18.6   58.0         62.0
# 2     0.01               73.219243         64.0   18.1   62.0         64.0
# 3     0.01               78.184215         67.0   17.6   67.0         67.0
# 4     0.01                7.097109         68.0   17.2   68.0         68.0
#
#     HIV/AIDS         GDP  Population  Schooling
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print ("Histogram : ")
plt.style.use('seaborn')
plt.figure(figsize=(18,9))
sns.distplot(le["Life expectancy "], kde=True, color='darkblue')
plt.title(f'Distribusi variable Life expectancy', size = 25)
plt.xlabel('Life Expectancy', size = 20)
plt.ylabel('Count', size = 20)
plt.grid(True)
plt.show()
# Out:
# Histogram :
# C:\Users\Odie Husain\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
le.head()
# Out:
#        Country      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  Developing              65.0            263.0             62
# 1  Afghanistan  Developing              59.9            271.0             64
# 2  Afghanistan  Developing              59.9            268.0             66
# 3  Afghanistan  Developing              59.5            272.0             69
# 4  Afghanistan  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B   BMI   Polio  Diphtheria   \
# 0     0.01               71.279624         65.0   19.1    6.0         65.0
# 1     0.01               73.523582         62.0   18.6   58.0         62.0
# 2     0.01               73.219243         64.0   18.1   62.0         64.0
# 3     0.01               78.184215         67.0   17.6   67.0         67.0
# 4     0.01                7.097109         68.0   17.2   68.0         68.0
#
#     HIV/AIDS         GDP  Population  Schooling
# ...

# %%
le.columns
# Out:
# Index(['Country', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        'Schooling'],
#       dtype='object')

# %%
variables = ["Life expectancy ", "percentage expenditure", "Adult Mortality", "infant deaths"]

for i in variables :
    print (f"Untuk variable {i}")
    df1 = le.groupby("Status").mean()
    plt.figure(figsize=(10,5))
    plt.style.use('seaborn')
    plt.bar(df1.index ,df1[i])
    plt.title(f'Perbandingan Variabel {i} untuk Setiap Status', size = 15)
    plt.ylabel(f"{i}")
    plt.xlabel('status')
    plt.show()
# Out:
# Untuk variable Life expectancy
# Untuk variable percentage expenditure
# Untuk variable Adult Mortality
# Untuk variable infant deaths

# %%
le.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 2938 non-null   object
#  1   Status                  2938 non-null   object
#  2   Life expectancy         2928 non-null   float64
#  3   Adult Mortality         2928 non-null   float64
#  4   infant deaths           2938 non-null   int64
#  5   Alcohol                 2744 non-null   float64
#  6   percentage expenditure  2938 non-null   float64
#  7   Hepatitis B             2385 non-null   float64
#  8    BMI                    2904 non-null   float64
#  9   Polio                   2919 non-null   float64
#  10  Diphtheria              2919 non-null   float64
#  11   HIV/AIDS               2938 non-null   float64
#  12  GDP                     2490 non-null   float64
#  13  Population              2286 non-null   float64
# ...

# %%
le.columns
# Out:
# Index(['Country', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        'Schooling'],
#       dtype='object')

# %%
for i in  le.columns:
    print (f"untuk variable {i}")
    jumlah_na = le[i].isna().sum()/len(le)*100
    print(f"Jumlah null valuenya adalah sebanyak {jumlah_na}%")
    print("\n")
# Out:
# untuk variable Country
# Jumlah null valuenya adalah sebanyak 0.0%
#
#
# untuk variable Status
# Jumlah null valuenya adalah sebanyak 0.0%
#
#
# untuk variable Life expectancy
# Jumlah null valuenya adalah sebanyak 0.3403675970047651%
#
#
# untuk variable Adult Mortality
# Jumlah null valuenya adalah sebanyak 0.3403675970047651%
#
#
# untuk variable infant deaths
# Jumlah null valuenya adalah sebanyak 0.0%
#
#
# untuk variable Alcohol
# Jumlah null valuenya adalah sebanyak 6.603131381892443%
#
#
# untuk variable percentage expenditure
# Jumlah null valuenya adalah sebanyak 0.0%
#
#
# untuk variable Hepatitis B
# Jumlah null valuenya adalah sebanyak 18.82232811436351%
#
#
# untuk variable  BMI
# Jumlah null valuenya adalah sebanyak 1.1572498298162015%
#
#
# untuk variable Polio
# Jumlah null valuenya adalah sebanyak 0.6466984343090538%
#
#
# untuk variable Diphtheria
# Jumlah null valuenya adalah sebanyak 0.6466984343090538%
#
#
# untuk variable  HIV/AIDS
# ...

# %%
def normal_saphiro(col) :
    from scipy.stats import shapiro
    SStat, SPval = shapiro(le[col])

    if SPval > 0.05 :
        # Distribusi Normal
        print (f"SPvalnya adalah : {SPval}")
        return True 

    else :
        # Tidak Distribusi Normal
        print (f"SPvalnya adalah : {SPval}")
        return False

# %%
variables = ['Life expectancy ', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       'Schooling']

for i in variables:
    nama_var = i
    print(f"\nUntuk Variabel {nama_var}")
    if (normal_saphiro(nama_var)) :
        rata2 = le[nama_var].mean()
        le[nama_var] = le[nama_var].fillna(value=rata2)
        print(f"Missing value sudah diganti dengan Mean. Yaitu adalah {rata2}")
    else :
        median = le[nama_var].describe()["50%"]
        le[nama_var] = le[nama_var].fillna(value=median)
        print(f"Missing value sudah diganti dengan Median. Yaitu adalah {median}")
# Out:
# Untuk Variabel Life expectancy
# SPvalnya adalah : 1.0
# Missing value sudah diganti dengan Mean. Yaitu adalah 69.22493169398908
#
# Untuk Variabel Adult Mortality
# SPvalnya adalah : 1.0
# Missing value sudah diganti dengan Mean. Yaitu adalah 164.79644808743168
#
# Untuk Variabel infant deaths
# SPvalnya adalah : 0.0
# Missing value sudah diganti dengan Median. Yaitu adalah 3.0
#
# Untuk Variabel Alcohol
# SPvalnya adalah : 1.0
# Missing value sudah diganti dengan Mean. Yaitu adalah 4.602860787172012
#
# Untuk Variabel percentage expenditure
# SPvalnya adalah : 0.0
# Missing value sudah diganti dengan Median. Yaitu adalah 64.912906045
#
# Untuk Variabel Hepatitis B
# SPvalnya adalah : 1.0
# Missing value sudah diganti dengan Mean. Yaitu adalah 80.94046121593291
#
# Untuk Variabel  BMI
# SPvalnya adalah : 1.0
# Missing value sudah diganti dengan Mean. Yaitu adalah 38.321246556473824
#
# Untuk Variabel Polio
# SPvalnya adalah : 1.0
# ...

# %%
le.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 2938 non-null   object
#  1   Status                  2938 non-null   object
#  2   Life expectancy         2938 non-null   float64
#  3   Adult Mortality         2938 non-null   float64
#  4   infant deaths           2938 non-null   int64
#  5   Alcohol                 2938 non-null   float64
#  6   percentage expenditure  2938 non-null   float64
#  7   Hepatitis B             2938 non-null   float64
#  8    BMI                    2938 non-null   float64
#  9   Polio                   2938 non-null   float64
#  10  Diphtheria              2938 non-null   float64
#  11   HIV/AIDS               2938 non-null   float64
#  12  GDP                     2938 non-null   float64
#  13  Population              2938 non-null   float64
# ...

# %%
le_dummy = pd.get_dummies(le, drop_first=True, columns=['Status'])

# %%
le_dummy.head()
# Out:
#        Country  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan              65.0            263.0             62     0.01
# 1  Afghanistan              59.9            271.0             64     0.01
# 2  Afghanistan              59.9            268.0             66     0.01
# 3  Afghanistan              59.5            272.0             69     0.01
# 4  Afghanistan              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B   BMI   Polio  Diphtheria    HIV/AIDS  \
# 0               71.279624         65.0   19.1    6.0         65.0        0.1
# 1               73.523582         62.0   18.6   58.0         62.0        0.1
# 2               73.219243         64.0   18.1   62.0         64.0        0.1
# 3               78.184215         67.0   17.6   67.0         67.0        0.1
# 4                7.097109         68.0   17.2   68.0         68.0        0.1
#
#           GDP  Population  Schooling  Status_Developing
# ...

# %%
X = le_dummy[['Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       'Schooling', 'Status_Developing']]
y = le_dummy['Life expectancy ']

# %%
import statsmodels.api as sm

# %%
regresi = sm.OLS(y, sm.add_constant(X))
hasil = regresi.fit()
print(hasil.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     914.0
# Date:                Tue, 27 Jul 2021   Prob (F-statistic):               0.00
# Time:                        14:03:41   Log-Likelihood:                -8402.1
# No. Observations:                2938   AIC:                         1.683e+04
# Df Residuals:                    2924   BIC:                         1.692e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     55.8256      0.613     91.084      0.000      54.624      57.027
# ...

# %%
X2 = le_dummy[['Adult Mortality',
       'infant deaths', 'Hepatitis B',
       ' BMI ', 'Polio', 'Diphtheria ', ' HIV/AIDS', 'GDP',
       'Schooling', 'Status_Developing']]
y2 = le_dummy['Life expectancy ']

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X2, y2, train_size = 0.8, random_state = 2020)

# %%
regresi = sm.OLS(Ytrain, sm.add_constant(Xtrain))
hasil = regresi.fit()
print(hasil.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Life expectancy    R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     942.1
# Date:                Tue, 27 Jul 2021   Prob (F-statistic):               0.00
# Time:                        14:39:16   Log-Likelihood:                -6709.9
# No. Observations:                2350   AIC:                         1.344e+04
# Df Residuals:                    2339   BIC:                         1.351e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                56.3673      0.675     83.498      0.000      55.043      57.691
# ...

# %%
Xtest.columns
# Out:
# Index(['Adult Mortality', 'infant deaths', 'Hepatitis B', ' BMI ', 'Polio',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Schooling', 'Status_Developing'],
#       dtype='object')

# %%
Data = pd.DataFrame()
Data['Life expectancy '] = Ytest
Data['Prediksi'] = round((55.9605 + (-0.02090*Xtest['Adult Mortality']) + (-0.0027*Xtest['infant deaths']) + (-0.0209*Xtest['Hepatitis B']) +
                    (0.0571*Xtest[' BMI ']) + (0.0325*Xtest['Polio']) + (0.0526*Xtest['Diphtheria ']) + (-0.4889*Xtest[' HIV/AIDS']) + (4.974e-05*Xtest['GDP']) +
                    (0.9567*Xtest['Schooling']) + (-2.0797*Xtest['Status_Developing'])), 1)
Data['Error'] = round((55.9605 + (-0.02090*Xtest['Adult Mortality']) + (-0.0027*Xtest['infant deaths']) + (-0.0209*Xtest['Hepatitis B']) +
                    (0.0571*Xtest[' BMI ']) + (0.0325*Xtest['Polio']) + (0.0526*Xtest['Diphtheria ']) + (-0.4889*Xtest[' HIV/AIDS']) + (4.974e-05*Xtest['GDP']) +
                    (0.9567*Xtest['Schooling']) + (-2.0797*Xtest['Status_Developing'])) - Data['Life expectancy '], 1)
Data
# Out:
#       Life expectancy   Prediksi  Error
# 2073              77.9      77.1   -0.8
# 2154              64.6      66.0    1.4
# 153               69.2      66.8   -2.4
# 603               59.8      63.2    3.4
# 723               58.8      63.7    4.9
# ...                ...       ...    ...
# 2119              75.0      75.4    0.4
# 1639              83.0      77.5   -5.5
# 1354              65.3      70.9    5.6
# 2417              53.1      51.7   -1.4
# 181               76.1      72.9   -3.2
#
# [588 rows x 3 columns]

# %%
MSE = sum(Data['Error']**2)/len(Data)
MSE
# Out:
# 18.624319727891162

# %%
Data['APE'] = abs((Data['Life expectancy '] - Data['Prediksi']) / Data['Life expectancy '])
Data
# Out:
#       Life expectancy   Prediksi  Error       APE
# 2073              77.9      77.1   -0.8  0.010270
# 2154              64.6      66.0    1.4  0.021672
# 153               69.2      66.8   -2.4  0.034682
# 603               59.8      63.2    3.4  0.056856
# 723               58.8      63.7    4.9  0.083333
# ...                ...       ...    ...       ...
# 2119              75.0      75.4    0.4  0.005333
# 1639              83.0      77.5   -5.5  0.066265
# 1354              65.3      70.9    5.6  0.085758
# 2417              53.1      51.7   -1.4  0.026365
# 181               76.1      72.9   -3.2  0.042050
#
# [588 rows x 4 columns]

# %%
MAPE = np.mean(Data['APE'])
print (f'Nilai MAPE adalah Sebesar {round(MAPE*100,2)} %')
# Out:
# Nilai MAPE adalah Sebesar 5.05 %

# %% [markdown]
# ## UJI ASUMSI

# %% [markdown]
# ## UJI NORMALITAS

# %%
plt.figure (figsize=(20,10))
sns.set_context ('notebook', font_scale=2)
sns.distplot(hasil.resid)
plt.xlabel('Residual', fontsize = 20)
# Out:
# C:\Users\Odie Husain\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Residual')

# %%
sm.qqplot(hasil.resid, line = '45')
plt.show()
# Out:
# C:\Users\Odie Husain\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
from scipy.stats import shapiro
shapiro(hasil.resid)
# Out:
# ShapiroResult(statistic=0.9814907908439636, pvalue=6.25630181545051e-17)

# %% [markdown]
# ## ASUMSI GAUSS-MARKOV

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(hasil.fittedvalues, hasil.resid)
sns.lineplot(hasil.fittedvalues, 0)
plt.ylabel('Residual', fontsize = 20)
plt.xlabel('Hasil Prediksi', fontsize = 20)
# Out:
# C:\Users\Odie Husain\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Odie Husain\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'Hasil Prediksi')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def hitung_vif (X) :
    vif = pd.DataFrame()
    vif['Variable'] = Xtest.columns
    vif['Nilai VIF'] = [variance_inflation_factor(Xtest.values, i) for i in range (Xtest.shape[1])]
    return vif

# %%
hitung_vif(Xtest[Xtest.columns])
# Out:
#             Variable  Nilai VIF
# 0    Adult Mortality   4.255620
# 1      infant deaths   1.116704
# 2        Hepatitis B  16.393166
# 3               BMI    6.527636
# 4              Polio  31.523619
# 5        Diphtheria   27.073295
# 6           HIV/AIDS   1.692072
# 7                GDP   1.967981
# 8          Schooling  20.348014
# 9  Status_Developing   6.041504

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, accuracy_score

# %%
scaler = MinMaxScaler()
scaler.fit(Xtrain)
X_train_Scaled = scaler.transform(Xtrain)
X_Test_Scaled = scaler.transform(Xtest)

# %%
# Find Best K
k = range(3,50,2) #(1,3,5,7,....,49)
testing_accuracy = []
training_accuracy = []
score = 0

for i in k:
    knn = KNeighborsRegressor(n_neighbors = i)
    knn.fit(X_train_Scaled, Ytrain)
    
    # y_pred_train = knn.predict(X_train_Scaled)
    # training_accuracy.append(knn.score(X_Test_Scaled, y_pred_train))
    
    y_pred_test = knn.predict(X_Test_Scaled)
    acc_score = knn.score(X_Test_Scaled, Ytest)
    testing_accuracy.append(acc_score)
    
    if score < acc_score:
        score = acc_score
        best_k = i
        print (k)

print('Best Accuracy Score', round(score,4), 'Best K-Score', best_k)
# Out:
# range(3, 50, 2)
# Best Accuracy Score 0.914 Best K-Score 3

# %%
knn = KNeighborsRegressor(n_neighbors = 3)
knn.fit(X_train_Scaled, Ytrain)
ypredict = knn.predict(X_Test_Scaled)
ypredict
# Out:
# array([75.36666667, 65.63333333, 69.16666667, 61.26666667, 63.        ,
#        81.13333333, 57.43333333, 79.73333333, 77.26666667, 71.93333333,
#        73.46666667, 47.3       , 82.43333333, 56.73333333, 69.1       ,
#        85.1       , 76.03333333, 53.8       , 64.73333333, 65.73333333,
#        71.6       , 75.73333333, 83.56666667, 74.53333333, 59.23333333,
#        74.36666667, 64.76666667, 83.        , 58.13333333, 72.9       ,
#        66.36666667, 74.83333333, 56.23333333, 55.96666667, 74.26666667,
#        52.96666667, 70.93333333, 73.46666667, 51.13333333, 83.33333333,
#        69.2       , 65.03333333, 73.43333333, 74.43333333, 74.06666667,
#        73.53333333, 74.5       , 79.86666667, 72.43333333, 74.9       ,
#        69.86666667, 76.76666667, 83.66666667, 84.03333333, 77.53333333,
#        64.56666667, 72.33333333, 62.26666667, 72.6       , 63.26666667,
#        73.76666667, 57.03333333, 67.93333333, 54.96666667, 47.46666667,
# ...

# %%
akurasi = knn.score(X_Test_Scaled, Ytest)*100

print (f'Akurasi dengan Scaling : ')
print (f'Untuk n=3 adalah {akurasi} %')
# Out:
# Akurasi dengan Scaling :
# Untuk n=3 adalah 91.40134356787298 %

# %%
Data = pd.DataFrame()
Data['Life expectancy '] = Ytest
Data['Prediksi'] = ypredict
Data['Error'] = ypredict - Data['Life expectancy ']

Data
# Out:
#       Life expectancy    Prediksi     Error
# 2073              77.9  75.366667 -2.533333
# 2154              64.6  65.633333  1.033333
# 153               69.2  69.166667 -0.033333
# 603               59.8  61.266667  1.466667
# 723               58.8  63.000000  4.200000
# ...                ...        ...       ...
# 2119              75.0  77.866667  2.866667
# 1639              83.0  80.300000 -2.700000
# 1354              65.3  65.833333  0.533333
# 2417              53.1  53.800000  0.700000
# 181               76.1  76.133333  0.033333
#
# [588 rows x 3 columns]

# %%
MSE = sum(Data['Error']**2)/len(Data)
MSE
# Out:
# 8.257815450650552

# %%
Data['APE'] = abs((Data['Life expectancy '] - Data['Prediksi']) / Data['Life expectancy '])
Data
# Out:
#       Life expectancy    Prediksi     Error       APE
# 2073              77.9  75.366667 -2.533333  0.032520
# 2154              64.6  65.633333  1.033333  0.015996
# 153               69.2  69.166667 -0.033333  0.000482
# 603               59.8  61.266667  1.466667  0.024526
# 723               58.8  63.000000  4.200000  0.071429
# ...                ...        ...       ...       ...
# 2119              75.0  77.866667  2.866667  0.038222
# 1639              83.0  80.300000 -2.700000  0.032530
# 1354              65.3  65.833333  0.533333  0.008167
# 2417              53.1  53.800000  0.700000  0.013183
# 181               76.1  76.133333  0.033333  0.000438
#
# [588 rows x 4 columns]

# %%
MAPE = np.mean(Data['APE'])
print (f'Nilai MAPE adalah Sebesar {round(MAPE*100,2)} %')
# Out:
# Nilai MAPE adalah Sebesar 2.87 %

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
scaler = MinMaxScaler()
scaler.fit(Xtrain)
X_train_scaled = scaler.transform(Xtrain)
X_test_scaled = scaler.transform(Xtest)

# %%
tree = DecisionTreeRegressor(criterion='mse')
tree.fit(X_train_scaled, Ytrain)
pred = tree.predict(X_test_scaled)
pred
# Out:
# array([76.8       , 66.1       , 72.8       , 60.        , 59.8       ,
#        81.9       , 59.2       , 78.7       , 77.8       , 71.3       ,
#        71.1       , 49.4       , 74.6       , 61.        , 69.        ,
#        81.1       , 77.2       , 53.5       , 63.7       , 63.3       ,
#        73.2       , 72.5       , 83.        , 75.3       , 59.3       ,
#        75.6       , 57.        , 78.7       , 59.8       , 73.7       ,
#        66.6       , 74.9       , 55.        , 52.1       , 78.9       ,
#        56.        , 67.1       , 68.7       , 52.4       , 89.        ,
#        65.1       , 64.3       , 72.5       , 71.8       , 68.3       ,
#        74.1       , 73.        , 76.3       , 69.9       , 75.4       ,
#        76.        , 76.3       , 78.2       , 81.9       , 78.        ,
#        66.        , 73.        , 62.8       , 72.7       , 63.2       ,
#        75.6       , 57.9       , 65.7       , 54.7       , 62.8       ,
# ...

# %%
akurasi = tree.score(X_Test_Scaled, Ytest)*100

print (f'Akurasi dengan Scaling : {akurasi}% ')
# Out:
# Akurasi dengan Scaling : 94.07872012089055%

# %%
Data = pd.DataFrame()
Data['Life expectancy '] = Ytest
Data['Prediksi'] = pred
Data['Error'] = pred - Data['Life expectancy ']

Data
# Out:
#       Life expectancy   Prediksi  Error
# 2073              77.9      76.8   -1.1
# 2154              64.6      66.1    1.5
# 153               69.2      72.8    3.6
# 603               59.8      60.0    0.2
# 723               58.8      59.8    1.0
# ...                ...       ...    ...
# 2119              75.0      76.0    1.0
# 1639              83.0      79.6   -3.4
# 1354              65.3      65.0   -0.3
# 2417              53.1      51.4   -1.7
# 181               76.1      77.6    1.5
#
# [588 rows x 3 columns]

# %%
MSE = sum(Data['Error']**2)/len(Data)
MSE
# Out:
# 5.6865670653666065

# %%
Data['APE'] = abs((Data['Life expectancy '] - Data['Prediksi']) / Data['Life expectancy '])
Data
# Out:
#       Life expectancy   Prediksi  Error       APE
# 2073              77.9      76.8   -1.1  0.014121
# 2154              64.6      66.1    1.5  0.023220
# 153               69.2      72.8    3.6  0.052023
# 603               59.8      60.0    0.2  0.003344
# 723               58.8      59.8    1.0  0.017007
# ...                ...       ...    ...       ...
# 2119              75.0      76.0    1.0  0.013333
# 1639              83.0      79.6   -3.4  0.040964
# 1354              65.3      65.0   -0.3  0.004594
# 2417              53.1      51.4   -1.7  0.032015
# 181               76.1      77.6    1.5  0.019711
#
# [588 rows x 4 columns]

# %%
MAPE = np.mean(Data['APE'])
print (f'Nilai MAPE adalah Sebesar {round(MAPE*100,2)} %')
# Out:
# Nilai MAPE adalah Sebesar 2.29 %

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
scaler = MinMaxScaler()
scaler.fit(Xtrain)
X_train_scaled = scaler.transform(Xtrain)
X_test_scaled = scaler.transform(Xtest)

# %%
regr = make_pipeline(StandardScaler(), SVR())
regr.fit(X_train_scaled, Ytrain)
ysvr = regr.predict(X_Test_Scaled)
ysvr
# Out:
# array([74.79964701, 65.69122113, 69.86809623, 61.54881545, 63.42711502,
#        80.07545562, 57.72303452, 74.09501878, 77.70334588, 71.37479776,
#        75.00344416, 53.97123575, 80.09979382, 59.60288576, 71.73452555,
#        80.5347604 , 75.68994527, 54.49429364, 63.79894766, 68.21014925,
#        72.8930192 , 73.72618192, 78.51436017, 72.88510612, 57.73176651,
#        73.65399134, 62.26781186, 82.4874888 , 58.92063584, 74.98347099,
#        68.37533284, 74.66248572, 58.53628107, 56.84310315, 78.86062995,
#        54.10575026, 69.1150231 , 75.09541673, 51.06010621, 81.28258922,
#        67.03382234, 66.73305516, 71.10767482, 72.42358359, 68.52585566,
#        73.80992294, 73.3582635 , 78.25395216, 74.75229214, 73.01251866,
#        73.54440318, 75.78286629, 80.90303011, 79.87830749, 81.47930559,
#        65.29609264, 71.71664796, 63.09130654, 73.14170349, 64.30252924,
#        74.13119829, 56.5599442 , 70.77978319, 54.36024731, 56.66587634,
# ...

# %%
akurasi = regr.score(X_Test_Scaled, Ytest)*100

print (f'Akurasi dengan Scaling : {akurasi}% ')
# Out:
# Akurasi dengan Scaling : 87.09558045152275%

# %%
Data = pd.DataFrame()
Data['Life expectancy '] = Ytest
Data['Prediksi'] = ysvr
Data['Error'] = ysvr - Data['Life expectancy ']

Data
# Out:
#       Life expectancy    Prediksi     Error
# 2073              77.9  74.799647 -3.100353
# 2154              64.6  65.691221  1.091221
# 153               69.2  69.868096  0.668096
# 603               59.8  61.548815  1.748815
# 723               58.8  63.427115  4.627115
# ...                ...        ...       ...
# 2119              75.0  74.548944 -0.451056
# 1639              83.0  78.914077 -4.085923
# 1354              65.3  66.195579  0.895579
# 2417              53.1  58.395248  5.295248
# 181               76.1  76.022845 -0.077155
#
# [588 rows x 3 columns]

# %%
MSE = sum(Data['Error']**2)/len(Data)
MSE
# Out:
# 12.392903004118823

# %%
Data['APE'] = abs((Data['Life expectancy '] - Data['Prediksi']) / Data['Life expectancy '])
Data
# Out:
#       Life expectancy    Prediksi     Error       APE
# 2073              77.9  74.799647 -3.100353  0.039799
# 2154              64.6  65.691221  1.091221  0.016892
# 153               69.2  69.868096  0.668096  0.009655
# 603               59.8  61.548815  1.748815  0.029244
# 723               58.8  63.427115  4.627115  0.078692
# ...                ...        ...       ...       ...
# 2119              75.0  74.548944 -0.451056  0.006014
# 1639              83.0  78.914077 -4.085923  0.049228
# 1354              65.3  66.195579  0.895579  0.013715
# 2417              53.1  58.395248  5.295248  0.099722
# 181               76.1  76.022845 -0.077155  0.001014
#
# [588 rows x 4 columns]

# %%
MAPE = np.mean(Data['APE'])
print (f'Nilai MAPE adalah Sebesar {round(MAPE*100,2)} %')
# Out:
# Nilai MAPE adalah Sebesar 3.74 %
